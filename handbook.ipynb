# %% [markdown]
# <a href="https://colab.research.google.com/github/huongd17at089/rice_diseases_detection/blob/master/handbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huongd17at089/rice_diseases_detection.git
# Out:
# Cloning into 'rice_diseases_detection'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 9 (delta 0), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
import os
import numpy as np
import cv2
path = "data/rn"

# %%
imgs = []

# %%
img = cv2.imread("/content/data/z2648948017243_2dfcd179fd2b304982d6039f1201238a.jpg")
img = cv2.resize(img,(225,225))
# arr = np.array(img)
imgs.append([img,"label"])
# arr = np.array(imgs)

# %%
img = cv2.imread("/content/data/z2648948017243_2dfcd179fd2b304982d6039f1201238a.jpg")
img = cv2.resize(img,(225,225))
# arr = np.array(img)
imgs.append([img,"label2"])
arr = np.array(imgs)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """

# %%
arr.shape
# Out:
# (2, 2)

# %%
import matplotlib.pyplot as plt

imgs = arr[: , 0]
labels = arr[ :, 1]
plt.figure(figsize=(10,10))
plt.imshow(imgs[0])
plt.title(labels[0])
# Out:
# Text(0.5, 1.0, 'label')

# %%
size = 4
data = np.arange(size * size).reshape((size, size))

# Limits for the extent
x_start = 3.0
x_end = 9.0
y_start = 6.0
y_end = 12.0

extent = [x_start, x_end, y_start, y_end]

# The normal figure
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
im = ax.imshow(data, extent=extent, origin='lower', interpolation='None', cmap='viridis')

# Add the text
jump_x = (x_end - x_start) / (2.0 * size)
jump_y = (y_end - y_start) / (2.0 * size)
x_positions = np.linspace(start=x_start, stop=x_end, num=size, endpoint=False)
y_positions = np.linspace(start=y_start, stop=y_end, num=size, endpoint=False)

for y_index, y in enumerate(y_positions):
    for x_index, x in enumerate(x_positions):
        label = data[y_index, x_index]
        text_x = x + jump_x
        text_y = y + jump_y
        ax.text(text_x, text_y, label, color='black', ha='center', va='center')

fig.colorbar(im)
plt.show()

# %%
import numpy as np

def rgb2hex(r, g, b):
    return '#%02x%02x%02x' % (r, g, b)

vfunc = np.vectorize(rgb2hex)

a = (np.random.uniform(0,1,(10,5,5,3))*255).astype(int)

c = vfunc(a[:,:,:,0], a[:,:,:,1], a[:,:,:,2])

f = c.reshape((10,25))

# %%
len(f.flatten())
# Out:
# 250

# %%
len(np.unique(data.flatten()))
# Out:
# 16

# %%
imgs = []

# %%
img = cv2.imread("/content/bla.jpg")
img = cv2.resize(img,(50,50))
# arr = np.array(img)
# imgs.append([img,"label2"])
# arr = np.array(imgs)

# %%
import matplotlib.pyplot as plt

imgs = arr[: , 0]
labels = arr[ :, 1]
plt.figure(figsize=(10,10))
plt.imshow(imgs[0])
plt.title(labels[0])
# Out:
# Text(0.5, 1.0, 'label2')

# %%
arr[: , 0][0]
# Out:
# array([[[225, 232, 235],
#         [226, 233, 236],
#         [226, 233, 236],
#         ...,
#         [226, 233, 236],
#         [225, 232, 235],
#         [226, 233, 236]],
#
#        [[231, 238, 241],
#         [231, 238, 241],
#         [231, 238, 241],
#         ...,
#         [231, 238, 241],
#         [231, 238, 241],
#         [231, 238, 241]],
#
#        [[235, 242, 245],
#         [235, 242, 245],
#         [235, 242, 245],
#         ...,
#         [235, 242, 245],
#         [235, 242, 245],
#         [235, 242, 245]],
#
#        ...,
#
#        [[240, 247, 250],
#         [240, 247, 250],
#         [240, 247, 250],
#         ...,
#         [240, 247, 250],
#         [240, 247, 250],
#         [240, 247, 250]],
#
#        [[240, 247, 250],
#         [240, 247, 250],
#         [240, 247, 250],
#         ...,
#         [240, 247, 250],
#         [240, 247, 250],
#         [240, 247, 250]],
#
#        [[240, 247, 250],
#         [240, 247, 250],
#         [240, 247, 250],
# ...

# %%
import numpy as np

def rgb2hex(r, g, b):
    return '#%02x%02x%02x' % (r, g, b)

vfunc = np.vectorize(rgb2hex)

a = arr[: , 0][0]

c = vfunc(a[:,:,0], a[:,:,1], a[:,:,2])

f = c.reshape((50,50))

# %%
f
# Out:
# array([['#e1e8eb', '#e2e9ec', '#e2e9ec', ..., '#e2e9ec', '#e1e8eb',
#         '#e2e9ec'],
#        ['#e7eef1', '#e7eef1', '#e7eef1', ..., '#e7eef1', '#e7eef1',
#         '#e7eef1'],
#        ['#ebf2f5', '#ebf2f5', '#ebf2f5', ..., '#ebf2f5', '#ebf2f5',
#         '#ebf2f5'],
#        ...,
#        ['#f0f7fa', '#f0f7fa', '#f0f7fa', ..., '#f0f7fa', '#f0f7fa',
#         '#f0f7fa'],
#        ['#f0f7fa', '#f0f7fa', '#f0f7fa', ..., '#f0f7fa', '#f0f7fa',
#         '#f0f7fa'],
#        ['#f0f7fa', '#f0f7fa', '#f0f7fa', ..., '#f0f7fa', '#f0f7fa',
#         '#f0f7fa']], dtype='<U7')

# %%
len(f.flatten())
# Out:
# 2500

# %%
temp = np.unique(f.flatten()).tolist()

# %%
def replace_with_dict(ar, dic):
    k = np.array(list(dic.keys()))
    v = np.array(list(dic.values()))
    sidx = k.argsort()
    return v[sidx[np.searchsorted(k,ar,sorter=sidx)]]

# %%
dic = dict(zip(temp, list(range(len(temp)))))

# %%
data = replace_with_dict(f, dic)

# %%
size = 50
data = data.reshape((size, size))

# Limits for the extent
x_start = 3.0
x_end = 9.0
y_start = 6.0
y_end = 12.0

extent = [x_start, x_end, y_start, y_end]

# The normal figure
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
im = ax.imshow(arr[: , 0][0], extent=extent, origin='lower', interpolation='None')

# Add the text
jump_x = (x_end - x_start) / (2.0 * size)
jump_y = (y_end - y_start) / (2.0 * size)
x_positions = np.linspace(start=x_start, stop=x_end, num=size, endpoint=False)
y_positions = np.linspace(start=y_start, stop=y_end, num=size, endpoint=False)

for y_index, y in enumerate(y_positions):
    for x_index, x in enumerate(x_positions):
        label = data[y_index, x_index]
        text_x = x + jump_x
        text_y = y + jump_y
        ax.text(text_x, text_y, label, color='black', ha='center', va='center')

plt.savefig("/content/oke.jpg")

# fig.colorbar(im)
# plt.show()

# %%
plt.savefig("/content/oke.jpg")
